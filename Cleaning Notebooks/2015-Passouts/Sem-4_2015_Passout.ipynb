# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
% matplotlib inline

# %%
path = "../../Data/Exam Data/2015/CMPN SEM-IV_2013_june.xlsx"

# %%
sem_4_2015_df = pd.read_excel(path)

# %%
sem_4_2015_df
# Out:
#      EXAM SEAT NO.                NAME OF CANDIDATE AM IV Unnamed: 3  \
# NaN            NaN                              NaN    TH        NaN
# NaN            NaN                              MAX   100        NaN
# NaN            NaN                              MIN    40        NaN
# NaN       134201.0          AMIN RISHITA VIJAYKUMAR    40        NaN
# NaN       134202.0            AMRE PRITAM ANILKUMAR    64        NaN
# NaN       134203.0               ANSAN SUNNY SALAMA    42          E
# NaN       134204.0            ASRANI BHARTI LACHMAN    52        NaN
# NaN       134205.0                BADE AMIT KERAMBA    40        NaN
# NaN       134206.0                BAGWE KARAN VINAY    65        NaN
# NaN       134207.0        BANDIVADEKAR RUTALI DILIP    61        NaN
# NaN       134208.0           BARBHAYA RISHI DIVYESH    20          F
# NaN       134209.0     BELWALKAR MANALI CHANDRAKANT    63        NaN
# NaN       134210.0              BHAGAT DOLLY DEEPAK    40        NaN
# ...

# %%
sem_4_2015_df.dropna(subset=['EXAM SEAT NO.'],inplace=True)

# %%
sem_4_2015_df.dropna(axis=0, how='all',inplace=True)

# %%
sem_4_2015_df.index = sem_4_2015_df['EXAM SEAT NO.']

# %%
sem_4_2015_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 182 entries, 134201.0 to 134382.0
# Data columns (total 40 columns):
# EXAM SEAT NO.        182 non-null float64
# NAME OF CANDIDATE    182 non-null object
# AM IV                182 non-null object
# Unnamed: 3           79 non-null object
# Unnamed: 4           182 non-null object
# Unnamed: 5           95 non-null object
# ADC                  182 non-null object
# Unnamed: 7           79 non-null object
# Unnamed: 8           182 non-null object
# Unnamed: 9           95 non-null object
# DBMS                 182 non-null object
# Unnamed: 11          90 non-null object
# Unnamed: 12          182 non-null object
# Unnamed: 13          95 non-null object
# Unnamed: 14          182 non-null object
# Unnamed: 15          95 non-null object
# CG                   182 non-null object
# Unnamed: 17          90 non-null object
# Unnamed: 18          182 non-null object
# Unnamed: 19          95 non-null object
# ...

# %%
sem_4_2015_df.columns.values[[3,4,5,7,8,9]] = ['AMIV_Grade','AMIV_TW','AMIV_TW_Grade','ADC_Grade','ADC_TW','ADC_TW_Grade']
sem_4_2015_df.columns.values[[11,12,13,14,15]] = ['DBMS_Grade','DBMS_TW','DBMS_TW_Grade','DBMS_Practical','DBMS_Practical_Grade']
sem_4_2015_df.columns.values[[17,18,19,20,21]] = ['CG_Grade','CG_TW','CG_TW_Grade','CG_Practical','CG_Practical_Grade']
sem_4_2015_df.columns.values[[23,24,25,26,27]] = ['AAD_Grade','AAD_TW','AAD_TW_Grade','AAD_Practical','AAD_Practical_Grade']
sem_4_2015_df.columns.values[[29,30,31,32,33]] = ['OS_Grade','OS_TW','OS_TW_Grade','OS_Practical','OS_Practical_Grade']

# %%
sem_4_2015_df = sem_4_2015_df.rename_axis(lambda x: x, 1, True)

# %%
sem_4_2015_df
# Out:
#                EXAM SEAT NO.                 NAME OF CANDIDATE AM IV  \
# EXAM SEAT NO.
# 134201.0            134201.0           AMIN RISHITA VIJAYKUMAR    40
# 134202.0            134202.0             AMRE PRITAM ANILKUMAR    64
# 134203.0            134203.0                ANSAN SUNNY SALAMA    42
# 134204.0            134204.0             ASRANI BHARTI LACHMAN    52
# 134205.0            134205.0                 BADE AMIT KERAMBA    40
# 134206.0            134206.0                 BAGWE KARAN VINAY    65
# 134207.0            134207.0         BANDIVADEKAR RUTALI DILIP    61
# 134208.0            134208.0            BARBHAYA RISHI DIVYESH    20
# 134209.0            134209.0      BELWALKAR MANALI CHANDRAKANT    63
# 134210.0            134210.0               BHAGAT DOLLY DEEPAK    40
# 134211.0            134211.0          BHALERAO DEVENDRA SURESH    17
# 134212.0            134212.0          BHOITE KISHORI PRABHAKAR    40
# ...
