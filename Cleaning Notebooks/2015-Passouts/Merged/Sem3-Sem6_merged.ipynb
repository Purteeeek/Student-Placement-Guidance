# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
% matplotlib inline

# %%
sem3 = "/Users/prashant/Downloads/Student-Placement-Guidance/Cleaned-Data/2015-Passouts/Sem-3_2015_Passout_cleaned.xlsx"
sem4 = "/Users/prashant/Downloads/Student-Placement-Guidance/Cleaned-Data/2015-Passouts/Sem-4_2015_Passout_cleaned.xlsx"
sem5 = "/Users/prashant/Downloads/Student-Placement-Guidance/Cleaned-Data/2015-Passouts/Sem-5_2015_Passout_cleaned.xlsx"
sem6 = "/Users/prashant/Downloads/Student-Placement-Guidance/Cleaned-Data/2015-Passouts/Sem-6_2015_Passout_cleaned.xlsx"

# %%
sem3_df = pd.read_excel(sem3)
sem4_df = pd.read_excel(sem4)
sem5_df = pd.read_excel(sem5)
sem6_df = pd.read_excel(sem6)

# %%
#sem3_df.info()

# %%
sem3_df = sem3_df.drop(['EXAM SEAT NO..1', 'AMIII_Grade', 'AMIII_TW_Grade', 'EDLC_Grade.1', 'EDLC_Grade', 'EDLC_Practical_Grade','DSGT_Grade', 'DSGT_TW_Grade'], axis=1)
sem3_df = sem3_df.drop(['DLDA_Grade', 'DLDA_TW_Grade', 'DSF_Grade', 'DSF_Grade.1', 'DSF_Practical_Grade', 'COA_Grade', 'COA_TW_Grade', 'PCT_Grade', 'Marks_in_words'], axis=1)
sem3_df = sem3_df.rename(columns = {'TOTAL': 'Total III', 'REMARKS':'REMARKS 3'})
sem3_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 20 columns):
# EXAM SEAT NO.        243 non-null object
# NAME OF CANDIDATE    243 non-null object
# AM III               167 non-null float64
# AMIII_TW             156 non-null float64
# EDLC                 171 non-null float64
# EDLC_TW              157 non-null float64
# EDLC_Practical       155 non-null float64
# DSGT                 156 non-null float64
# DSGT_TW              156 non-null float64
# DLDA                 156 non-null float64
# DLDA_TW              243 non-null object
# DSF                  150 non-null float64
# DSF_TW               156 non-null float64
# DSF_Practical        154 non-null float64
# COA                  161 non-null float64
# COA_TW               156 non-null float64
# PCT                  156 non-null float64
# Total III            235 non-null float64
# REMARKS 3            241 non-null object
# Marks_numerical      231 non-null float64
# ...

# %%
sem4_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 41 columns):
# EXAM SEAT NO.           182 non-null int64
# EXAM SEAT NO..1         182 non-null int64
# NAME OF CANDIDATE       182 non-null object
# AM IV                   171 non-null float64
# AMIV_Grade              79 non-null object
# AMIV_TW                 182 non-null int64
# AMIV_TW_Grade           95 non-null object
# ADC                     175 non-null float64
# ADC_Grade               79 non-null object
# ADC_TW                  182 non-null int64
# ADC_TW_Grade            95 non-null object
# DBMS                    179 non-null float64
# DBMS_Grade              90 non-null object
# DBMS_TW                 182 non-null int64
# DBMS_TW_Grade           95 non-null object
# DBMS_Practical          182 non-null int64
# DBMS_Practical_Grade    95 non-null object
# CG                      177 non-null float64
# CG_Grade                90 non-null object
# ...

# %%
sem4_df = sem4_df.drop(['EXAM SEAT NO..1', 'AMIV_Grade', 'AMIV_TW_Grade', 'ADC_Grade', 'ADC_TW_Grade', 'DBMS_Grade', 'DBMS_TW_Grade', 'DBMS_Practical_Grade'], axis = 1)
sem4_df = sem4_df.drop(['CG_Grade', 'CG_TW_Grade', 'CG_Practical_Grade', 'AAD_Grade', 'AAD_TW_Grade', 'AAD_Practical_Grade', 'OS_Grade', 'OS_TW_Grade', 'OS_Practical_Grade', 'Unnamed: 39'], axis = 1)
sem4_df = sem4_df.rename(columns = {'GNT' : 'GNT 3-4', 'REMARK':'REMARK 4'})
sem4_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 23 columns):
# EXAM SEAT NO.        182 non-null int64
# NAME OF CANDIDATE    182 non-null object
# AM IV                171 non-null float64
# AMIV_TW              182 non-null int64
# ADC                  175 non-null float64
# ADC_TW               182 non-null int64
# DBMS                 179 non-null float64
# DBMS_TW              182 non-null int64
# DBMS_Practical       182 non-null int64
# CG                   177 non-null float64
# CG_TW                182 non-null int64
# CG_Practical         182 non-null int64
# AAD                  177 non-null float64
# AAD_TW               182 non-null int64
# AAD_Practical        182 non-null int64
# OS                   177 non-null float64
# OS_TW                182 non-null int64
# OS_Practical         182 non-null int64
# TOT IV               182 non-null int64
# TOT III              182 non-null int64
# ...

# %%
sem5_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 169 entries, 0 to 168
# Data columns (total 38 columns):
# EXAM SEAT NO.            169 non-null object
# NAME OF THE CANDIDATE    169 non-null object
# CN                       166 non-null float64
# CN_Grade                 65 non-null object
# CN_TW                    169 non-null int64
# CN_TW_Grade              68 non-null object
# CN_Practical             169 non-null int64
# CN_Practical_Grade       68 non-null object
# ADS                      166 non-null float64
# ADS_Grade                64 non-null object
# ADS_TW                   169 non-null int64
# ADS_TW_Grade             68 non-null object
# ADS_Practical            169 non-null int64
# ADS_Practical_Grade      68 non-null object
# MP                       163 non-null float64
# MP_Grade                 60 non-null object
# MP_TW                    169 non-null int64
# MP_TW_Grade              68 non-null object
# MP_Practical             169 non-null int64
# ...

# %%
sem5_df = sem5_df.drop(['CN_Grade', 'CN_TW_Grade', 'CN_Practical_Grade', 'ADS_Grade', 'ADS_TW_Grade', 'ADS_Practical_Grade', 'MP_Grade', 'MP_TW_Grade', 'MP_Practical_Grade'], axis=1)
sem5_df = sem5_df.drop(['TCS_Grade', 'TCS_TW_Grade', 'WE_Grade', 'WE_Practical_Grade', 'EVS_Grade', 'EVS_TW_Grade', 'Total_in_words', 'Unnamed: 37'], axis = 1)
sem5_df = sem5_df.rename(columns = {'TOTAL': 'Total V', 'REMARK':'REMARK 5', 'NAME OF THE CANDIDATE' :'NAME OF CANDIDATE'})
#sem5_df.head(1)
sem5_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 169 entries, 0 to 168
# Data columns (total 21 columns):
# EXAM SEAT NO.        169 non-null object
# NAME OF CANDIDATE    169 non-null object
# CN                   166 non-null float64
# CN_TW                169 non-null int64
# CN_Practical         169 non-null int64
# ADS                  166 non-null float64
# ADS_TW               169 non-null int64
# ADS_Practical        169 non-null int64
# MP                   163 non-null float64
# MP_TW                169 non-null int64
# MP_Practical         169 non-null int64
# TCS                  161 non-null float64
# TCS_TW               169 non-null int64
# WE                   163 non-null float64
# WE_TW                169 non-null int64
# WE_TW_Grade          68 non-null object
# WE_Practical         169 non-null int64
# EVS                  167 non-null float64
# EVS_TW               169 non-null int64
# Total V              169 non-null int64
# ...

# %%
sem6_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 43 columns):
# EXAM SEAT NO.            161 non-null object
# EXAM SEAT NO..1          161 non-null object
# NAME OF THE CANDIDATE    161 non-null object
# ACN                      158 non-null float64
# ACN_Grade                15 non-null object
# ACN_TW                   161 non-null int64
# ACN_TW_Grade             19 non-null object
# ACN_P&O                  161 non-null int64
# ACN_P&O_Grade            19 non-null object
# SPCC                     156 non-null float64
# SPCC_Grade               14 non-null object
# SPCC_TW                  161 non-null int64
# SPCC_TW_Grade            19 non-null object
# SPCC_P&O                 161 non-null int64
# SPCC_P&O_Grade           19 non-null object
# OOSE                     158 non-null float64
# OOSE_Grade               15 non-null object
# OOSE_TW                  161 non-null int64
# OOSE_TW_Grade            19 non-null object
# ...

# %%
sem6_df = sem6_df.drop(['EXAM SEAT NO..1', "ACN_Grade", "ACN_TW_Grade", "ACN_P&O_Grade", "SPCC_Grade", "SPCC_TW_Grade", "SPCC_P&O_Grade", "OOSE_Grade","OOSE_TW_Grade", "OOSE_P&O_Grade"], axis=1)
sem6_df = sem6_df.drop(["AMP_Grade", "AMP_TW_Grade","AMP_P&O_Grade", "DWM_Grade", "DWM_TW_Grade", "DWM_P&O_Grade", "SEMR_Grade", "SEMR_P&O_Grade", "Unnamed: 41"], axis=1)
sem6_df = sem6_df.rename(columns = {'GNT' : 'GNT 5-6', 'REMARK': 'REMARK 6', 'NAME OF THE CANDIDATE': 'NAME OF CANDIDATE'})
#sem6_df.head(1)
sem6_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 24 columns):
# EXAM SEAT NO.        161 non-null object
# NAME OF CANDIDATE    161 non-null object
# ACN                  158 non-null float64
# ACN_TW               161 non-null int64
# ACN_P&O              161 non-null int64
# SPCC                 156 non-null float64
# SPCC_TW              161 non-null int64
# SPCC_P&O             161 non-null int64
# OOSE                 158 non-null float64
# OOSE_TW              161 non-null int64
# OOSE_P&O             161 non-null int64
# AMP                  156 non-null float64
# AMP_TW               161 non-null int64
# AMP_P&O              161 non-null int64
# DWM                  158 non-null float64
# DWM_TW               161 non-null int64
# DWM_P&O              161 non-null int64
# SEMR                 161 non-null int64
# SEMR_P&O             161 non-null int64
# TOT VI               161 non-null int64
# ...

# %%
sem3_to_sem6_merge_df = pd.concat([sem3_df, sem4_df.set_index('NAME OF CANDIDATE'), sem5_df.set_index('NAME OF CANDIDATE'), sem6_df.set_index('NAME OF CANDIDATE')], axis=1, join='inner')
sem3_to_sem6_merge_df.head(10)
# Out:
#                              EXAM SEAT NO.  AM III  AMIII_TW  EDLC  EDLC_TW  \
# NAME OF CANDIDATE
# AMIN RISHITA VIJAYKUMAR             223201    20.0      17.0  42.0     23.0
# AMRE PRITAM ANILKUMAR               223202    40.0      23.0  70.0     20.0
# ANSAN SUNNY SALAMA                  223203    40.0      17.0  40.0     20.0
# ASRANI BHARTI LACHMAN               223204    41.0      23.0  71.0     23.0
# BADE AMIT KERAMBA                   223205    14.0      15.0  53.0     20.0
# BAGWE KARAN VINAY                   223206    48.0      20.0  76.0     18.0
# BANDIVADEKAR RUTALI DILIP           223207    69.0      21.0  83.0     23.0
# BARBHAYA RISHI DIVYESH              223208    10.0      15.0  49.0     21.0
# BELWALKAR MANALI CHANDRAKANT        223209    45.0      21.0  50.0     19.0
# BHAGAT DOLLY DEEPAK                 223210    27.0      16.0  57.0     20.0
#
#                               EDLC_Practical  DSGT  DSGT_TW  DLDA DLDA_TW  \
# NAME OF CANDIDATE
# ...

# %%
sem3_to_sem6_merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 114 entries, AMIN RISHITA VIJAYKUMAR to RANE YUGANDHARA CHANDRAMOHAN
# Data columns (total 84 columns):
# EXAM SEAT NO.      114 non-null object
# AM III             112 non-null float64
# AMIII_TW           113 non-null float64
# EDLC               113 non-null float64
# EDLC_TW            113 non-null float64
# EDLC_Practical     113 non-null float64
# DSGT               113 non-null float64
# DSGT_TW            113 non-null float64
# DLDA               113 non-null float64
# DLDA_TW            114 non-null object
# DSF                113 non-null float64
# DSF_TW             113 non-null float64
# DSF_Practical      113 non-null float64
# COA                108 non-null float64
# COA_TW             113 non-null float64
# PCT                113 non-null float64
# Total III          107 non-null float64
# REMARKS 3          114 non-null object
# Marks_numerical    103 non-null float64
# EXAM SEAT NO.      114 non-null int64
# ...

# %%
#sem3_to_sem6_merge_df.index = sem3_to_sem6_merge_df['EXAM SEAT NO.']
#sem3_to_sem6_merge_df.head()

# %%
sem3_to_sem6_merge_df.describe()
# Out:
#            AM III    AMIII_TW        EDLC     EDLC_TW  EDLC_Practical  \
# count  112.000000  113.000000  113.000000  113.000000      113.000000
# mean    32.196429   17.070796   53.982301   20.442478       18.433628
# std     17.131626    3.288825   14.668955    1.977273        1.132917
# min      0.000000   10.000000   14.000000   17.000000       17.000000
# 25%     17.750000   15.000000   43.000000   19.000000       18.000000
# 50%     40.000000   17.000000   55.000000   20.000000       18.000000
# 75%     42.000000   18.000000   64.000000   22.000000       19.000000
# max     83.000000   24.000000   85.000000   24.000000       24.000000
#
#              DSGT     DSGT_TW        DLDA         DSF      DSF_TW  \
# count  113.000000  113.000000  113.000000  113.000000  113.000000
# mean    56.769912   19.008850   20.663717   45.982301   19.026549
# std     15.556354    2.965563    2.210408   11.970188    2.512327
# min     16.000000   12.000000   14.000000    2.000000   13.000000
# ...

# %%
placements_path = "/Users/prashant/Downloads/Student-Placement-Guidance/Data/Placement Data/Cleaned/2015.xlsx"
placement_df = pd.read_excel(placements_path)
placement_df = placement_df.rename(columns = {'NAME':'NAME OF CANDIDATE'})
placement_df.head()
# Out:
#               NAME OF CANDIDATE          Company
# 0         AMRE PRITAM ANILKUMAR          Vistaar
# 1         ASRANI BHARTI LACHMAN    Tech Mahindra
# 2             BAGWE KARAN VINAY          Infosys
# 3     BANDIVADEKAR RUTALI DILIP          Infosys
# 4  BELWALKAR MANALI CHANDRAKANT  Bista Solutions

# %%
# Merging all semester marks with placement data
merge_with_company  = pd.merge(sem3_to_sem6_merge_df, placement_df, on = 'NAME OF CANDIDATE', how='left')
merge_with_company.head()
# Out:
#          NAME OF CANDIDATE EXAM SEAT NO.  AM III  AMIII_TW  EDLC  EDLC_TW  \
# 0  AMIN RISHITA VIJAYKUMAR        223201    20.0      17.0  42.0     23.0
# 1    AMRE PRITAM ANILKUMAR        223202    40.0      23.0  70.0     20.0
# 2       ANSAN SUNNY SALAMA        223203    40.0      17.0  40.0     20.0
# 3    ASRANI BHARTI LACHMAN        223204    41.0      23.0  71.0     23.0
# 4        BADE AMIT KERAMBA        223205    14.0      15.0  53.0     20.0
#
#    EDLC_Practical  DSGT  DSGT_TW  DLDA      ...       DWM_TW  DWM_P&O  SEMR  \
# 0            18.0  44.0     19.0  20.0      ...           21       20    21
# 1            19.0  76.0     23.0  21.0      ...           22       22    21
# 2            17.0  44.0     18.0  20.0      ...           20       18    22
# 3            18.0  62.0     20.0  20.0      ...           20       20    21
# 4            19.0  40.0     18.0  21.0      ...           19       18    21
#
# ...

# %%
writer = pd.ExcelWriter('2015_merged.xlsx')

# %%
merge_with_company.to_excel(writer,"2015_merged")
writer.save()

# %% [markdown]
# ## Removing unnecessary columns in the file

# %%
cleaning_df = merge_with_company.drop(['EXAM SEAT NO.', 'Marks_numerical', 'CLASS'], axis = 1)
cleaning_df.head()
# Out:
#          NAME OF CANDIDATE  AM III  AMIII_TW  EDLC  EDLC_TW  EDLC_Practical  \
# 0  AMIN RISHITA VIJAYKUMAR    20.0      17.0  42.0     23.0            18.0
# 1    AMRE PRITAM ANILKUMAR    40.0      23.0  70.0     20.0            19.0
# 2       ANSAN SUNNY SALAMA    40.0      17.0  40.0     20.0            17.0
# 3    ASRANI BHARTI LACHMAN    41.0      23.0  71.0     23.0            18.0
# 4        BADE AMIT KERAMBA    14.0      15.0  53.0     20.0            19.0
#
#    DSGT  DSGT_TW  DLDA DLDA_TW      ...         DWM  DWM_TW  DWM_P&O  SEMR  \
# 0  44.0     19.0  20.0      20      ...        49.0      21       20    21
# 1  76.0     23.0  21.0      21      ...        55.0      22       22    21
# 2  44.0     18.0  20.0      20      ...        55.0      20       18    22
# 3  62.0     20.0  20.0      20      ...        58.0      20       20    21
# 4  40.0     18.0  21.0      21      ...        40.0      19       18    21
#
# ...

# %%
writer = pd.ExcelWriter('Cleaning.xlsx')

# %%
cleaning_df.to_excel(writer, 'Cleaning')
writer.save()
