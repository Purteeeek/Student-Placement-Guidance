# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
% matplotlib inline

# %%
path = "../../Data/Exam Data/2015/CMPN SEM-V DEC13.xlsx"

# %%
sem_5_2015_df = pd.read_excel(path)

# %%
sem_5_2015_df
# Out:
#     EXAM SEAT NO.             NAME OF THE CANDIDATE   CN Unnamed: 3  \
# 0             NaN                               NaN   TH        NaN
# 1             NaN                              MAX   100        NaN
# 2             NaN                              MIN    40        NaN
# 3          235201        ADMANE PRADEEP VIDNYANRAO    50        NaN
# 4          235202               AHIRE NAMRATA ASHOK   41        NaN
# 5          235203           AMIN RISHITA VIJAYKUMAR   44        NaN
# 6          235204             AMRE PRITAM ANILKUMAR   63        NaN
# 7          235205                ANSAN SUNNY SALAMA   45          E
# 8          235206             ASRANI BHARTI LACHMAN   56          E
# 9          235207                 BADE AMIT KERAMBA   42          E
# 10         235208                 BAGWE KARAN VINAY   74        NaN
# 11         235209         BANDIVADEKAR RUTALI DILIP   72        NaN
# 12         235210            BARBHAYA RISHI DIVYESH   82        NaN
# ...

# %%
sem_5_2015_df.dropna(subset=['EXAM SEAT NO.'],inplace=True)

# %%
sem_5_2015_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 169 entries, 3 to 171
# Data columns (total 38 columns):
# EXAM SEAT NO.            169 non-null object
# NAME OF THE CANDIDATE    169 non-null object
# CN                       169 non-null object
# Unnamed: 3               65 non-null object
# Unnamed: 4               169 non-null object
# Unnamed: 5               68 non-null object
# Unnamed: 6               169 non-null object
# Unnamed: 7               68 non-null object
# ADS                      169 non-null object
# Unnamed: 9               64 non-null object
# Unnamed: 10              169 non-null object
# Unnamed: 11              68 non-null object
# Unnamed: 12              169 non-null object
# Unnamed: 13              68 non-null object
# MP                       169 non-null object
# Unnamed: 15              60 non-null object
# Unnamed: 16              169 non-null object
# Unnamed: 17              68 non-null object
# Unnamed: 18              169 non-null object
# ...

# %%
sem_5_2015_df.columns.values[[3,4,5,6,7]] = ['CN_Grade','CN_TW','CN_TW_Grade','CN_Practical','CN_Practical_Grade']
sem_5_2015_df.columns.values[[9,10,11,12,13]] = ['ADS_Grade','ADS_TW','ADS_TW_Grade','ADS_Practical','ADS_Practical_Grade']
sem_5_2015_df.columns.values[[15,16,17,18,19]] = ['MP_Grade','MP_TW','MP_TW_Grade','MP_Practical','MP_Practical_Grade']
sem_5_2015_df.columns.values[[25,26,27,28,29]] = ['WE_Grade','WE_TW','WE_TW_Grade','WE_Practical','WE_Practical_Grade']
sem_5_2015_df.columns.values[[21,22,23]] = ['TCS_Grade','TCS_TW','TCS_TW_Grade']
sem_5_2015_df.columns.values[[31,32,33]] = ['EVS_Grade','EVS_TW','EVS_TW_Grade']
sem_5_2015_df.columns.values[[36]] = ["Total_in_words"]

# %%
sem_5_2015_df = sem_5_2015_df.rename_axis(lambda x: x, 1, True)

# %%
sem_5_2015_df
# Out:
#     EXAM SEAT NO.             NAME OF THE CANDIDATE   CN CN_Grade CN_TW  \
# 3          235201        ADMANE PRADEEP VIDNYANRAO    50      NaN    20
# 4          235202               AHIRE NAMRATA ASHOK   41      NaN    22
# 5          235203           AMIN RISHITA VIJAYKUMAR   44      NaN    23
# 6          235204             AMRE PRITAM ANILKUMAR   63      NaN    23
# 7          235205                ANSAN SUNNY SALAMA   45        E    21
# 8          235206             ASRANI BHARTI LACHMAN   56        E    23
# 9          235207                 BADE AMIT KERAMBA   42        E    20
# 10         235208                 BAGWE KARAN VINAY   74      NaN    20
# 11         235209         BANDIVADEKAR RUTALI DILIP   72      NaN    23
# 12         235210            BARBHAYA RISHI DIVYESH   82      NaN    21
# 13         235211      BELWALKAR MANALI CHANDRAKANT   56      NaN    23
# 14         235212               BHAGAT DOLLY DEEPAK   52      NaN    23
# ...

# %%
sem_5_2015_df['CN'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
sem_5_2015_df['CN_TW'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
sem_5_2015_df['CN_Practical'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
sem_5_2015_df['ADS'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
sem_5_2015_df['ADS_TW'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
sem_5_2015_df['ADS_Practical'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
sem_5_2015_df['MP'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
sem_5_2015_df['MP_TW'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
sem_5_2015_df['MP_Practical'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
sem_5_2015_df['WE'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
sem_5_2015_df['WE_TW'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
sem_5_2015_df['WE_Practical'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
sem_5_2015_df['TCS'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
sem_5_2015_df['TCS_TW'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
sem_5_2015_df['EVS'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
sem_5_2015_df['EVS_TW'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')

# %%
sem_5_2015_df
# Out:
#     EXAM SEAT NO.             NAME OF THE CANDIDATE  CN CN_Grade CN_TW  \
# 3          235201        ADMANE PRADEEP VIDNYANRAO   50      NaN    20
# 4          235202               AHIRE NAMRATA ASHOK  41      NaN    22
# 5          235203           AMIN RISHITA VIJAYKUMAR  44      NaN    23
# 6          235204             AMRE PRITAM ANILKUMAR  63      NaN    23
# 7          235205                ANSAN SUNNY SALAMA  45        E    21
# 8          235206             ASRANI BHARTI LACHMAN  56        E    23
# 9          235207                 BADE AMIT KERAMBA  42        E    20
# 10         235208                 BAGWE KARAN VINAY  74      NaN    20
# 11         235209         BANDIVADEKAR RUTALI DILIP  72      NaN    23
# 12         235210            BARBHAYA RISHI DIVYESH  82      NaN    21
# 13         235211      BELWALKAR MANALI CHANDRAKANT  56      NaN    23
# 14         235212               BHAGAT DOLLY DEEPAK  52      NaN    23
# ...
